# %%
pip install opencv-python

# %%
import cv2

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
img= cv2.imread("sg.png",0)
print(img)

print("Shape : ", img.shape)
# Out:
# [[187 158 104 121 143]
#  [198 125 255 255 147]
#  [209 134 255  97 182]]
# Shape :  (3, 5)

# %%
import numpy as np

np.concatenate((img,img,img,img,img,img))

cv2.imwrite("newmodified.png",np.concatenate((img,img,img,img,img,img)))
# Out:
# True

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#bgr
test = np.array([[[255, 100, 100],[125, 255, 0],[0, 0, 255]],[[255, 0, 0],[0, 255, 0],[0, 0, 255]],[[255, 0, 0],[0, 255, 0],[0, 0, 255]]])
print(test)
cv2.imwrite("test.png",test)
# Out:
# [[[255 100 100]
#   [125 255   0]
#   [  0   0 255]]
#
#  [[255   0   0]
#   [  0 255   0]
#   [  0   0 255]]
#
#  [[255   0   0]
#   [  0 255   0]
#   [  0   0 255]]]
# True

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
img = cv2.imread("test.png",0)
cv2.imwrite("grayscaletest.png",img)
# Out:
# True

# %%
#Change colorful image to grayscale
img = cv2.imread("av.png",0)
cv2.imwrite("grayscaleav.png",img)
# Out:
# True
